# %% [markdown]
# ## Model Training (CryoSleep TRUE)

# %% [markdown]
# ### Environment setting

# %%
import pickle
import os
import itertools
import pandas as pd
import numpy as np
#from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
#from sklearn.neighbors import KNeighborsClassifier
#from sklearn.linear_model import RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from utilsML import run_experiments, expand_parameters, time_gridsearch, constrained_combinations
#from utilsFE import process_features

# %% [markdown]
# ### Read processed data

# %%
cache_file = "procData.pkl"
cache_dir = "cache"
try:
    with open(os.path.join(cache_dir, cache_file), "rb") as f:
        cache_data = pickle.load(f)
    print("Read preprocessed data from cache file:", cache_file)
except:
    pass
# Out:
# Read preprocessed data from cache file: procData.pkl

# %%
proc_data = cache_data['proc_data']
df_train = proc_data[proc_data['CryoSleep'] == True].copy()
df_train.head(5).T
# Out:
#                                            7               9               10  \
# PassengerId                           0006_02         0008_01         0008_02
# HomePlanet                              Earth          Europa          Europa
# CryoSleep                                True            True            True
# Cabin                                   G/0/S           B/1/P           B/1/P
# Destination                       TRAPPIST-1e     55 Cancri e     TRAPPIST-1e
# Age                                 -0.055109       -1.031359        0.363284
# VIP                                     False           False           False
# RoomService                         -0.333105       -0.333105       -0.333105
# FoodCourt                           -0.281027       -0.281027       -0.281027
# ShoppingMall                        -0.283579       -0.283579       -0.283579
# Spa                                 -0.270626       -0.270626       -0.270626
# VRDeck                              -0.263003       -0.263003       -0.263003
# Name                       Candra Jacostaffey  Erraiam Flatic  Altardr Flatic
# Transported                              True            True            True
# Deck                                        G               B               B
# Num                                         0               1               1
# Side                                        S               P               P
# Age12                                     0.0             0.0             0.0
# Num500                                    1.0             1.0             1.0
# TotalExpenses                             0.0             0.0             0.0
# log10_RoomService                   -0.638181       -0.638181       -0.638181
# log10_FoodCourt                      -0.65008        -0.65008        -0.65008
# log10_ShoppingMall                  -0.622995       -0.622995       -0.622995
# log10_Spa                           -0.664035       -0.664035       -0.664035
# log10_VRDeck                        -0.640034       -0.640034       -0.640034
# log10_TotalExpenses                 -1.152845       -1.152845       -1.152845
# log10_RoomService1                        1.0             1.0             1.0
# log10_FoodCourt1                          1.0             1.0             1.0
# log10_ShoppingMall1                       1.0             1.0             1.0
# log10_Spa1                                1.0             1.0             1.0
# log10_VRDeck1                             1.0             1.0             1.0
# log10_TotalExpenses1                      1.0             1.0             1.0
# VIP_True                                  0.0             0.0             0.0
# Destination_55 Cancri e                   0.0             1.0             0.0
# Destination_PSO J318.5-22                 0.0             0.0             0.0
# Destination_TRAPPIST-1e                   1.0             0.0             1.0
# HomePlanet_Earth                          1.0             0.0             0.0
# HomePlanet_Europa                         0.0             1.0             1.0
# HomePlanet_Mars                           0.0             0.0             0.0
# CryoSleep_True                            1.0             1.0             1.0
# Deck_A                                    0.0             0.0             0.0
# Deck_B                                    0.0             1.0             1.0
# Deck_C                                    0.0             0.0             0.0
# Deck_D                                    0.0             0.0             0.0
# Deck_E                                    0.0             0.0             0.0
# Deck_F                                    0.0             0.0             0.0
# Deck_G                                    1.0             0.0             0.0
# Deck_T                                    0.0             0.0             0.0
# Side_S                                    1.0             0.0             0.0
#
#                                     18                 21
# PassengerId                    0016_01            0020_01
# HomePlanet                        Mars              Earth
# CryoSleep                         True               True
# Cabin                            F/5/P              E/0/S
# Destination                TRAPPIST-1e        TRAPPIST-1e
# Age                           1.130339          -1.937878
# VIP                              False              False
# RoomService                  -0.333105          -0.333105
# FoodCourt                    -0.281027          -0.281027
# ShoppingMall                 -0.283579          -0.283579
# Spa                          -0.270626          -0.270626
# VRDeck                       -0.263003          -0.263003
# Name                        Alus Upead  Almary Brantuarez
# Transported                       True              False
# Deck                                 F                  E
# Num                                  5                  0
# Side                                 P                  S
# Age12                              0.0                1.0
# Num500                             1.0                1.0
# TotalExpenses                      0.0                0.0
# log10_RoomService            -0.638181          -0.638181
# log10_FoodCourt               -0.65008           -0.65008
# log10_ShoppingMall           -0.622995          -0.622995
# log10_Spa                    -0.664035          -0.664035
# log10_VRDeck                 -0.640034          -0.640034
# log10_TotalExpenses          -1.152845          -1.152845
# log10_RoomService1                 1.0                1.0
# log10_FoodCourt1                   1.0                1.0
# log10_ShoppingMall1                1.0                1.0
# log10_Spa1                         1.0                1.0
# log10_VRDeck1                      1.0                1.0
# log10_TotalExpenses1               1.0                1.0
# VIP_True                           0.0                0.0
# Destination_55 Cancri e            0.0                0.0
# Destination_PSO J318.5-22          0.0                0.0
# Destination_TRAPPIST-1e            1.0                1.0
# HomePlanet_Earth                   0.0                1.0
# HomePlanet_Europa                  0.0                0.0
# HomePlanet_Mars                    1.0                0.0
# CryoSleep_True                     1.0                1.0
# Deck_A                             0.0                0.0
# Deck_B                             0.0                0.0
# Deck_C                             0.0                0.0
# Deck_D                             0.0                0.0
# Deck_E                             0.0                1.0
# Deck_F                             1.0                0.0
# Deck_G                             0.0                0.0
# Deck_T                             0.0                0.0
# Side_S                             0.0                1.0

# %%
X_train = df_train.drop('Transported', axis=1)
y_train = df_train['Transported']

# %% [markdown]
# #### Brute force approach

# %% [markdown]
# All possible combinations of features are built and tested with several hyperparameter configurations.

# %%
# Buils list of list with features to combine
# TODO Could this be improved?
onehot_homeplanet = (list(filter(lambda x: any(map(lambda y: y in x,['HomePlanet_'])), df_train.columns)))
main_homeplanet = list(filter(lambda x: any(map(lambda y: y not in x, ['Mars'])),onehot_homeplanet))
onehot_destination = (list(filter(lambda x: any(map(lambda y: y in x,['Destination_'])), df_train.columns)))
main_destination = list(filter(lambda x: any(map(lambda y: y not in x, ['TRAPPIST'])),onehot_destination))
onehot_deck = (list(filter(lambda x: any(map(lambda y: y in x,['Deck_'])), df_train.columns)))

list_of_features = [['Age','Age12'], 
                    ['Num','Num500'],
                    ['Side_S'], 
                    ['Deck_G',['Deck_G','Deck_C','Deck_B','Deck_F'], onehot_deck],
                    [['HomePlanet_Earth'],main_homeplanet],
                    [['Destination_55 Cancri e'],main_destination]
                   ]

# %%
# Test with largest list of features and more complicated model to check time and then build test
lst_datasets = constrained_combinations(list_of_features)
print(f'Number of datasets to test: {len(lst_datasets)}\n')
features_max = list(filter(lambda x: len(x) == max(list(map(len, lst_datasets))), lst_datasets))[1]
features_min = list(filter(lambda x: len(x) == min(list(map(len, lst_datasets))), lst_datasets))[1]

params = {'max_depth': np.arange(3, 22, 3),
          'min_samples_leaf': np.arange(3, 22, 3),
          'min_samples_split': np.arange(3, 22, 3),
          'splitter': ['random', 'best']}
grid = GridSearchCV(DecisionTreeClassifier(criterion='gini'), param_grid = params, 
                    cv = 5, scoring= 'accuracy', n_jobs = 3)

time_min, num_tests_min = time_gridsearch(grid, features_min, X_train, y_train)
print(f'Num features: {len(features_min)} Num comb hyperparam: {num_tests_min} Execution time: {time_min:.2f}')
time_max, num_tests_max = time_gridsearch(grid, features_max, X_train, y_train)
print(f'Num features: {len(features_max)} Num comb hyperparam: {num_tests_max} Execution time: {time_max:.2f}')
# Out:
# Number of datasets to test: 635
#
# Num features: 2 Num comb hyperparam: 686 Execution time: 6.72
# Num features: 15 Num comb hyperparam: 686 Execution time: 8.25

# %%
# combinations of model to check (algorithm + parameters)
#lst_datasets_sel = lst_datasets[:3]
dict_datasets = {f'dataset{i+1}': lst for i, lst in enumerate(lst_datasets)}
#dict_datasets = {f'dataset{i+1}': lst for i, lst in enumerate(lst_datasets_sel)}
experiments = {
    'model': ['DecisionTree'],
    'algorithms': [DecisionTreeClassifier(criterion='gini')],
    'parameters': [{'max_depth': np.arange(3, 22, 3),
                    'min_samples_leaf': np.arange(3, 22, 3),
                    'min_samples_split': np.arange(3, 22, 3),
                    'splitter': ['random', 'best']}]
}
results = run_experiments(dict_datasets, experiments, X_train, y_train, scoring = 'accuracy', n_jobs = 2)
# Out:
# Datasets analysis: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 635/635 [2:41:21<00:00, 15.25s/it]

# %%
# save results in cache
cache_data = dict(results_gridsearch=results)
cache_file = "resultGridSearchDecisionTreeCryoSleep.pkl"
cache_dir = "cache"
with open(os.path.join(cache_dir, cache_file), "wb") as f:
        pickle.dump(cache_data, f)
print("Wrote preprocessed data to cache file:", cache_file)
# Out:
# Wrote preprocessed data to cache file: resultGridSearchDecisionTreeCryoSleep.pkl

# %%
cache_file = "resultGridSearchDecisionTreeCryoSleep.pkl"
cache_dir = "cache"
try:
    with open(os.path.join(cache_dir, cache_file), "rb") as f:
        cache_data = pickle.load(f)
    print("Read preprocessed data from cache file:", cache_file)
except:
    pass
results = cache_data['results_gridsearch']
# Out:
# Read preprocessed data from cache file: resultGridSearch.pkl

# %%
df = pd.DataFrame(results).drop(['features'],axis=1)
df_max = df.sort_values(['test_score'], ascending=[False]).head(10)
expand_parameters(df_max)
# Out:
#        feature_name         model  train_score  test_score  fit_time  \
# 114478   dataset167  DecisionTree     0.834787    0.831091  0.003858
# 113516   dataset166  DecisionTree     0.828367    0.830758  0.003399
# 114218   dataset167  DecisionTree     0.827461    0.830099  0.003806
# 113606   dataset166  DecisionTree     0.832894    0.829777  0.003307
# 114880   dataset168  DecisionTree     0.830260    0.829773  0.003620
# 106200   dataset155  DecisionTree     0.819723    0.829115  0.003192
# 113434   dataset166  DecisionTree     0.830837    0.828785  0.003270
# 113546   dataset166  DecisionTree     0.827708    0.828784  0.003236
# 115088   dataset168  DecisionTree     0.830425    0.828783  0.003465
# 114498   dataset167  DecisionTree     0.827049    0.828458  0.003725
#
#         max_depth  min_samples_leaf  min_samples_split splitter
# 114478         21                 6                  3   random
# 113516         12                 9                  9   random
# 114218         12                12                 12   random
# 113606         15                 6                 18   random
# 114880         12                 6                 18   random
# 106200         18                15                 18   random
# 113434          9                12                 12   random
# 113546         12                15                 12   random
# 115088         18                 9                 15   random
# 114498         21                 9                 12   random

# %%
# top score datasets
print(lst_datasets[167])
print(lst_datasets[166])
print(lst_datasets[168])
# Out:
# ['Age', 'Side_S', 'Deck_A', 'Deck_B', 'Deck_C', 'Deck_D', 'Deck_E', 'Deck_F', 'Deck_G', 'Deck_T', 'HomePlanet_Earth', 'HomePlanet_Europa']
# ['Age', 'Side_S', 'Deck_A', 'Deck_B', 'Deck_C', 'Deck_D', 'Deck_E', 'Deck_F', 'Deck_G', 'Deck_T', 'HomePlanet_Earth', 'HomePlanet_Europa', 'Destination_55 Cancri e', 'Destination_PSO J318.5-22']
# ['Age', 'Side_S', 'Deck_A', 'Deck_B', 'Deck_C', 'Deck_D', 'Deck_E', 'Deck_F', 'Deck_G', 'Deck_T', 'Destination_55 Cancri e']

# %% [markdown]
# Best score is achieved for the dataset  'Age', 'Side_S', 'Deck_A', 'Deck_B', 'Deck_C', 'Deck_D', 'Deck_E', 'Deck_F', 'Deck_G', 'Deck_T', 'HomePlanet_Earth' and 'HomePlanet_Europa'.
#
# Final score for the validation dataset is 0.835

# %% [markdown]
# ### Random forest

# %% [markdown]
# The subsequent computations will evaluate two feature sets: the first corresponds to the top-performing combination from prior analysis, while the second additionally includes destination feature.

# %%
# test for checking time for a rum
features = ['Age', 'Side_S', 'Deck_A', 'Deck_B', 'Deck_C', 'Deck_D', 'Deck_E', 'Deck_F', 'Deck_G', 'Deck_T', 'HomePlanet_Earth', 'HomePlanet_Europa']

params = {'max_depth': np.arange(9, 13),
          'min_samples_leaf': np.arange(9, 13),
          'min_samples_split': np.arange(9, 13)}
grid = GridSearchCV(RandomForestClassifier(criterion='gini', n_estimators=200), param_grid = params, 
                    cv = 5, scoring= 'accuracy', n_jobs = 3)

time, num_tests = time_gridsearch(grid, features, X_train, y_train)
print(f'Num features: {len(features)} Num comb hyperparam: {num_tests} Execution time: {time:.2f}')
# Out:
# Num features: 12 Num comb hyperparam: 64 Execution time: 58.77

# %%
# combinations of model to check (algorithm + parameters)
dict_datasets = {'dataset166': lst_datasets[166],
                 'dataset167': lst_datasets[167],
                 'dataset168': lst_datasets[168]
}
experiments = {
    'model': ['RandomForest'],
    'algorithms': [RandomForestClassifier(criterion='gini')],
    'parameters': [{'n_estimators': [100, 150, 200],
                    'max_depth': np.arange(6, 15, 2),
                    'min_samples_leaf': np.arange(6, 15, 2),
                    'min_samples_split': np.arange(6, 15, 2)}]
}
results = run_experiments(dict_datasets, experiments, X_train, y_train, scoring = 'accuracy', n_jobs = 3)
# Out:
# Datasets analysis: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [11:30<00:00, 230.21s/it]

# %%
# save results in cache
cache_data = dict(results_gridsearch=results)
cache_file = "resultGridSearchRandomForestCryoSleep.pkl"
cache_dir = "cache"
with open(os.path.join(cache_dir, cache_file), "wb") as f:
        pickle.dump(cache_data, f)
print("Wrote preprocessed data to cache file:", cache_file)
# Out:
# Wrote preprocessed data to cache file: resultGridSearchRandomForestCryoSleep.pkl

# %%
cache_file = "resultGridSearchRandomForestCryoSleep.pkl"
cache_dir = "cache"
try:
    with open(os.path.join(cache_dir, cache_file), "rb") as f:
        cache_data = pickle.load(f)
    print("Read preprocessed data from cache file:", cache_file)
except:
    pass
results = cache_data['results_gridsearch']
# Out:
# Read preprocessed data from cache file: resultGridSearchRandomForest.pkl

# %%
df = pd.DataFrame(results).drop(['features'],axis=1)
df_max = df.sort_values(['feature_name','test_score'], ascending=[True,False]).groupby('feature_name').head(5)
expand_parameters(df_max)
# Out:
#     feature_name         model  train_score  test_score  fit_time  \
# 93    dataset166  RandomForest     0.832977    0.821537  0.195597
# 84    dataset166  RandomForest     0.834953    0.821210  0.198673
# 117   dataset166  RandomForest     0.829273    0.821209  0.194099
# 86    dataset166  RandomForest     0.835776    0.820880  0.422390
# 114   dataset166  RandomForest     0.829026    0.820548  0.193350
# 507   dataset167  RandomForest     0.832565    0.828452  0.196479
# 401   dataset167  RandomForest     0.830919    0.828124  0.401542
# 400   dataset167  RandomForest     0.830919    0.828123  0.286732
# 386   dataset167  RandomForest     0.832236    0.828122  0.385029
# 498   dataset167  RandomForest     0.833718    0.827467  0.194246
# 882   dataset168  RandomForest     0.833306    0.826147  0.203521
# 947   dataset168  RandomForest     0.834788    0.825820  0.419265
# 762   dataset168  RandomForest     0.828532    0.825817  0.193500
# 942   dataset168  RandomForest     0.835858    0.825489  0.211600
# 945   dataset168  RandomForest     0.834623    0.825489  0.210090
#
#      n_estimators  max_depth  min_samples_leaf  min_samples_split
# 93            100         12                12                 12
# 84            100         12                 8                 14
# 117           100         14                12                 10
# 86            100         12                10                  8
# 114           100         14                10                 14
# 507           150          6                 8                 10
# 401           100          8                 6                  8
# 400           100          8                 6                  6
# 386           100          6                10                  8
# 498           100         14                14                 12
# 882           150          6                 8                 10
# 947           150         10                14                 10
# 762           100          6                10                 10
# 942           150         10                12                 10
# 945           150         10                14                  6

# %%
expand_parameters(df.sort_values(['test_score'], ascending=[False]).head(1))
# Out:
#     feature_name         model  train_score  test_score  fit_time  \
# 507   dataset167  RandomForest     0.832565    0.828452  0.196479
#
#      n_estimators  max_depth  min_samples_leaf  min_samples_split
# 507           150          6                 8                 10

# %% [markdown]
# ### Boosted Tree

# %%
# test for checking time for a rum
features = lst_datasets[166]

params = {'max_depth': np.arange(3,11),
          'learning_rate': [0.001, 0.01, 0.1]}
grid = GridSearchCV(GradientBoostingClassifier(n_estimators=200), param_grid = params, 
                    cv = 5, scoring= 'accuracy', n_jobs = 3)

time, num_tests = time_gridsearch(grid, features, X_train, y_train)
print(f'Num features: {len(features)} Num comb hyperparam: {num_tests} Execution time: {time:.2f}')
# Out:
# Num features: 14 Num comb hyperparam: 24 Execution time: 56.95

# %%
# combinations of model to check (algorithm + parameters)
dict_datasets = {'dataset166': lst_datasets[166],
                 'dataset167': lst_datasets[167],
                 'dataset168': lst_datasets[168]
}
experiments = {
    'model': ['GradientBoosting'],
    'algorithms': [GradientBoostingClassifier()],
    'parameters': [{'n_estimators': [100, 150, 200],
                    'max_depth': np.arange(3, 11),
                    'learning_rate': [0.005, 0.01, 0.05]}]
}
results = run_experiments(dict_datasets, experiments, X_train, y_train, scoring = 'accuracy', n_jobs = 3)
# Out:
# Datasets analysis: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [05:58<00:00, 119.62s/it]

# %%
# save results in cache
cache_data = dict(results_gridsearch=results)
cache_file = "resultGridSearchGradientBoostingCryoSleep.pkl"
cache_dir = "cache"
with open(os.path.join(cache_dir, cache_file), "wb") as f:
        pickle.dump(cache_data, f)
print("Wrote preprocessed data to cache file:", cache_file)
# Out:
# Wrote preprocessed data to cache file: resultGridSearchGradientBoostingCryoSleep.pkl

# %%
cache_file = "resultGridSearchGradientBoostingCryoSleep.pkl"
cache_dir = "cache"
try:
    with open(os.path.join(cache_dir, cache_file), "rb") as f:
        cache_data = pickle.load(f)
    print("Read preprocessed data from cache file:", cache_file)
except:
    pass
results = cache_data['results_gridsearch']
# Out:
# Read preprocessed data from cache file: resultGridSearchGradientBoostingCryoSleep.pkl

# %%
df = pd.DataFrame(results).drop(['features'],axis=1)
df_max = df.sort_values(['feature_name','test_score'], ascending=[True,False]).groupby('feature_name').head(5)
expand_parameters(df_max)
# Out:
#     feature_name             model  train_score  test_score  fit_time  \
# 48    dataset166  GradientBoosting     0.839069    0.822856  0.315404
# 49    dataset166  GradientBoosting     0.841291    0.822199  0.394905
# 32    dataset166  GradientBoosting     0.842855    0.821541  0.937891
# 51    dataset166  GradientBoosting     0.846807    0.821539  0.359151
# 31    dataset166  GradientBoosting     0.835281    0.821538  0.711991
# 104   dataset167  GradientBoosting     0.841209    0.822527  0.732499
# 103   dataset167  GradientBoosting     0.835940    0.822196  0.549917
# 83    dataset167  GradientBoosting     0.832236    0.821865  0.918732
# 105   dataset167  GradientBoosting     0.832236    0.821865  0.456058
# 120   dataset167  GradientBoosting     0.836681    0.821865  0.215237
# 177   dataset168  GradientBoosting     0.835693    0.822523  0.610350
# 155   dataset168  GradientBoosting     0.835693    0.822194  0.986378
# 173   dataset168  GradientBoosting     0.833224    0.822194  0.554988
# 192   dataset168  GradientBoosting     0.831577    0.821537  0.210454
# 180   dataset168  GradientBoosting     0.841867    0.821207  0.660861
#
#      n_estimators  max_depth  learning_rate
# 48          200.0        3.0          0.005
# 49          200.0        3.0          0.010
# 32          150.0        5.0          0.050
# 51          200.0        4.0          0.005
# 31          150.0        5.0          0.010
# 104         150.0        5.0          0.050
# 103         150.0        5.0          0.010
# 83          100.0        6.0          0.050
# 105         150.0        6.0          0.005
# 120         200.0        3.0          0.005
# 177         150.0        6.0          0.005
# 155         100.0        6.0          0.050
# 173         150.0        4.0          0.050
# 192         200.0        3.0          0.005
# 180         150.0        7.0          0.005

# %%
expand_parameters(df.sort_values(['test_score'], ascending=[False]).head(1))
# Out:
#    feature_name             model  train_score  test_score  fit_time  \
# 48   dataset166  GradientBoosting     0.839069    0.822856  0.315404
#
#     n_estimators  max_depth  learning_rate
# 48         200.0        3.0          0.005

# %% [markdown]
# ### XGBoosted tree

# %%
# test for checking time for a rum
features = lst_datasets[166]

params = {'max_depth': np.arange(3,11),
          'eta': [0.001, 0.01, 0.1]}
grid = GridSearchCV(XGBClassifier(n_estimators=200), param_grid = params, 
                    cv = 5, scoring= 'accuracy', n_jobs = 3)

time, num_tests = time_gridsearch(grid, features, X_train, y_train)
print(f'Num features: {len(features)} Num comb hyperparam: {num_tests} Execution time: {time:.2f}')
# Out:
# Num features: 14 Num comb hyperparam: 24 Execution time: 5.81

# %%
# combinations of model to check (algorithm + parameters)
dict_datasets = {'dataset166': lst_datasets[166],
                 'dataset167': lst_datasets[167],
                 'dataset168': lst_datasets[168]
}
experiments = {
    'model': ['XGBoost'],
    'algorithms': [XGBClassifier()],
    'parameters': [{'n_estimators': [50, 100, 150],
                    'max_depth': np.arange(2, 9),
                    'eta': [0.01, 0.05, 0.1, 0.3, 0.5]}]
}
results = run_experiments(dict_datasets, experiments, X_train, y_train, scoring = 'accuracy', n_jobs = 3)
# Out:
# Datasets analysis: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:58<00:00, 19.56s/it]

# %%
# save results in cache
cache_data = dict(results_gridsearch=results)
cache_file = "resultGridSearchXGBoostCryoSleep.pkl"
cache_dir = "cache"
with open(os.path.join(cache_dir, cache_file), "wb") as f:
        pickle.dump(cache_data, f)
print("Wrote preprocessed data to cache file:", cache_file)
# Out:
# Wrote preprocessed data to cache file: resultGridSearchXGBoostCryoSleep.pkl

# %%
cache_file = "resultGridSearchXGBoostCryoSleep.pkl"
cache_dir = "cache"
try:
    with open(os.path.join(cache_dir, cache_file), "rb") as f:
        cache_data = pickle.load(f)
    print("Read preprocessed data from cache file:", cache_file)
except:
    pass
results = cache_data['results_gridsearch']
# Out:
# Read preprocessed data from cache file: resultGridSearchXGBoostCryoSleep.pkl

# %%
df = pd.DataFrame(results).drop(['features'],axis=1)
df_max = df.sort_values(['feature_name','test_score'], ascending=[True,False]).groupby('feature_name').head(5)
expand_parameters(df_max)
# Out:
#     feature_name    model  train_score  test_score  fit_time  n_estimators  \
# 30    dataset166  XGBoost     0.835282    0.827795  0.033030          50.0
# 25    dataset166  XGBoost     0.833718    0.825487  0.042222          50.0
# 28    dataset166  XGBoost     0.837340    0.824833  0.048502          50.0
# 48    dataset166  XGBoost     0.838163    0.824174  0.031075         100.0
# 17    dataset166  XGBoost     0.836682    0.824172  0.100046          50.0
# 130   dataset167  XGBoost     0.832730    0.827794  0.040976          50.0
# 135   dataset167  XGBoost     0.834129    0.827135  0.032551          50.0
# 119   dataset167  XGBoost     0.830918    0.826477  0.106384          50.0
# 153   dataset167  XGBoost     0.835776    0.825163  0.027507         100.0
# 116   dataset167  XGBoost     0.827132    0.824501  0.074843          50.0
# 224   dataset168  XGBoost     0.832483    0.823512  0.107024          50.0
# 227   dataset168  XGBoost     0.833059    0.822855  0.106658          50.0
# 229   dataset168  XGBoost     0.826967    0.822852  0.080664          50.0
# 237   dataset168  XGBoost     0.830343    0.822525  0.028422          50.0
# 226   dataset168  XGBoost     0.826062    0.822522  0.078044          50.0
#
#      max_depth   eta
# 30         8.0  0.01
# 25         7.0  0.01
# 28         7.0  0.30
# 48         4.0  0.30
# 17         5.0  0.10
# 130        7.0  0.01
# 135        8.0  0.01
# 119        4.0  0.50
# 153        4.0  0.30
# 116        4.0  0.05
# 224        4.0  0.50
# 227        5.0  0.10
# 229        5.0  0.50
# 237        7.0  0.10
# 226        5.0  0.05

# %%
expand_parameters(df.sort_values(['test_score'], ascending=[False]).head(1))
# Out:
#    feature_name    model  train_score  test_score  fit_time  n_estimators  \
# 30   dataset166  XGBoost     0.835282    0.827795   0.03303          50.0
#
#     max_depth   eta
# 30        8.0  0.01

# %% [markdown]
# ### Support vector machine

# %%
# test for checking time for a rum
features = lst_datasets[166]

params = {'kernel': ['linear','rbf','sigmoid'],
          'gamma': np.logspace(-1,-3,5)}
grid = GridSearchCV(SVC(), param_grid = params, 
                    cv = 5, scoring= 'accuracy', n_jobs = 3)

time, num_tests = time_gridsearch(grid, features, X_train, y_train)
print(f'Num features: {len(features)} Num comb hyperparam: {num_tests} Execution time: {time:.2f}')
# Out:
# Num features: 14 Num comb hyperparam: 15 Execution time: 4.54

# %%
# combinations of model to check (algorithm + parameters)
dict_datasets = {'dataset166': lst_datasets[166],
                 'dataset167': lst_datasets[167],
                 'dataset168': lst_datasets[168]
}
experiments = {
    'model': ['SVCnopoly','SVCpoly'],
    'algorithms': [SVC(),SVC(kernel='poly')],
    'parameters': [{'kernel':['linear', 'rbf', 'sigmoid'],
                    'gamma': np.logspace(-1,-4,10)},
                   {'degree': np.arange(3,9)}]
}
results = run_experiments(dict_datasets, experiments, X_train, y_train, scoring = 'accuracy', n_jobs = 3)
# Out:
# Datasets analysis: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [01:47<00:00, 35.69s/it]

# %%
# save results in cache
cache_data = dict(results_gridsearch=results)
cache_file = "resultGridSearchSVMCryoSleep.pkl"
cache_dir = "cache"
with open(os.path.join(cache_dir, cache_file), "wb") as f:
        pickle.dump(cache_data, f)
print("Wrote preprocessed data to cache file:", cache_file)
# Out:
# Wrote preprocessed data to cache file: resultGridSearchSVMCryoSleep.pkl

# %%
cache_file = "resultGridSearchSVMCryoSleep.pkl"
cache_dir = "cache"
try:
    with open(os.path.join(cache_dir, cache_file), "rb") as f:
        cache_data = pickle.load(f)
    print("Read preprocessed data from cache file:", cache_file)
except:
    pass
results = cache_data['results_gridsearch']
# Out:
# Read preprocessed data from cache file: resultGridSearchSVMCryoSleep.pkl

# %%
df = pd.DataFrame(results).drop(['features'],axis=1)
df_max = df.sort_values(['feature_name','test_score'], ascending=[True,False]).groupby('feature_name').head(5)
expand_parameters(df_max)
# Out:
#     feature_name      model  train_score  test_score  fit_time  kernel  \
# 0     dataset166  SVCnopoly     0.817583    0.817583  0.114222  linear
# 1     dataset166  SVCnopoly     0.817583    0.817583  0.165289  linear
# 3     dataset166  SVCnopoly     0.817583    0.817583  0.087748  linear
# 4     dataset166  SVCnopoly     0.817583    0.817583  0.153242  linear
# 5     dataset166  SVCnopoly     0.817583    0.817583  0.218071  linear
# 36    dataset167  SVCnopoly     0.817583    0.817583  0.080103  linear
# 37    dataset167  SVCnopoly     0.817583    0.817583  0.145503  linear
# 39    dataset167  SVCnopoly     0.817583    0.817583  0.080087  linear
# 40    dataset167  SVCnopoly     0.817583    0.817583  0.130686  linear
# 41    dataset167  SVCnopoly     0.817583    0.817583  0.217520  linear
# 103   dataset168    SVCpoly     0.818489    0.817913  0.392806     NaN
# 72    dataset168  SVCnopoly     0.817583    0.817583  0.074014  linear
# 73    dataset168  SVCnopoly     0.817583    0.817583  0.154246  linear
# 75    dataset168  SVCnopoly     0.817583    0.817583  0.071670  linear
# 76    dataset168  SVCnopoly     0.817583    0.817583  0.123806  linear
#
#         gamma  degree
# 0    0.100000     NaN
# 1    0.046416     NaN
# 3    0.010000     NaN
# 4    0.004642     NaN
# 5    0.002154     NaN
# 36   0.100000     NaN
# 37   0.046416     NaN
# 39   0.010000     NaN
# 40   0.004642     NaN
# 41   0.002154     NaN
# 103       NaN     4.0
# 72   0.100000     NaN
# 73   0.046416     NaN
# 75   0.010000     NaN
# 76   0.004642     NaN

# %%
expand_parameters(df.sort_values(['test_score'], ascending=[False]).head(1))
# Out:
#     feature_name    model  train_score  test_score  fit_time  degree
# 103   dataset168  SVCpoly     0.818489    0.817913  0.392806       4

# %% [markdown]
# Best score (0.831) is achieved using a Decision Tree (max_depth 21, min_samples_leaf 6, min_samples_split 3, splitter random)
#
# Features use in this model: 'Age', 'Side_S', 'Deck_A', 'Deck_B', 'Deck_C', 'Deck_D', 'Deck_E', 'Deck_F', 'Deck_G', 'Deck_T', 'HomePlanet_Earth', 'HomePlanet_Europa'

# %% [markdown]
# ### Train model

# %% [markdown]
# Model with the best score is trained

# %%
features = lst_datasets[167]
X_train_sel = X_train[features]
model = DecisionTreeClassifier(max_depth=21, min_samples_leaf=6, min_samples_split=3, splitter='random')
model.fit(X_train_sel, y_train)
y_pred = model.predict(X_train_sel)
y_train_pred = pd.Series(y_pred, name='Pred')
y_train.index = range(y_train.shape[0])
print(pd.crosstab(y_train, y_train_pred))
print(classification_report(y_train, y_train_pred))
# save the model
with open('models/DecisionTreeCryoSleepModel.pkl', 'wb') as file:
    pickle.dump(model, file)
# Out:
# Pred         False  True
# Transported
# False           58    496
# True            39   2444
#               precision    recall  f1-score   support
#
#        False       0.60      0.10      0.18       554
#         True       0.83      0.98      0.90      2483
#
#     accuracy                           0.82      3037
#    macro avg       0.71      0.54      0.54      3037
# weighted avg       0.79      0.82      0.77      3037

# %% [markdown]
# ### Test model

# %% [markdown]
# Model is tested after processing the data test with the same pipeline used for train data

# %%
# TODO load data
df_test = pd.read_csv('data/test.csv')
df_test.head(5)

# %%
# TODO same processing to test data
preprocessor = cache_data['preprocessor']
encoder = cache_data['encoder']
scaler_num = cache_data['scaler']
df_proc_test = process_features(df_test, preprocessor, encoder, scaler_num)

# %%
df_proc_test.head(4)

# %% [markdown]
# Prediction for data test (score = 0.80289)

# %%
X_test = df_proc_test[features]
y_pred = model.predict(X_test)
y_test_pred = list(map(lambda x: True if x == 1 else False, y_pred))
test_result = pd.DataFrame({'PassengerId': df_proc_test['PassengerId'], 'Transported': y_test_pred})
test_result.to_csv('test_result.csv', index=False)
